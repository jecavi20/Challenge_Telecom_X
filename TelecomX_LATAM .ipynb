# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd
import matplotlib.pyplot as plt

archivo = 'https://raw.githubusercontent.com/alura-cursos/challenge2-data-science-LATAM/refs/heads/main/TelecomX_Data.json'

df = pd.read_json(archivo)

df.head(10)
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 5  0013-MHZWF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6  0013-SMEOE    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 7  0014-BMAQU    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 8  0015-UOCOJ    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 9  0016-QLJIS    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
df.dtypes
# Out:
# customerID    object
# Churn         object
# customer      object
# phone         object
# internet      object
# account       object
# dtype: object

# %%
df.isnull().sum()
# Out:
# customerID    0
# Churn         0
# customer      0
# phone         0
# internet      0
# account       0
# dtype: int64

# %% [markdown]
# #🔧 Transformación

# %%
datos_customer= pd.json_normalize(df['customer'])

datos_customer
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
datos_phone= pd.json_normalize(df['phone'])

datos_phone.head(10)
# Out:
#   PhoneService MultipleLines
# 0          Yes            No
# 1          Yes           Yes
# 2          Yes            No
# 3          Yes            No
# 4          Yes            No
# 5          Yes            No
# 6          Yes            No
# 7          Yes           Yes
# 8          Yes            No
# 9          Yes           Yes

# %%
datos_internet = pd.json_normalize(df['internet'])
datos_internet.head(10)
# Out:
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No         Yes
# 1             DSL             No           No               No          No
# 2     Fiber optic             No           No              Yes          No
# 3     Fiber optic             No          Yes              Yes          No
# 4     Fiber optic             No           No               No         Yes
# 5             DSL             No           No               No         Yes
# 6     Fiber optic            Yes          Yes              Yes         Yes
# 7     Fiber optic            Yes           No               No         Yes
# 8             DSL            Yes           No               No          No
# 9             DSL            Yes          Yes              Yes         Yes
#
#   StreamingTV StreamingMovies
# 0         Yes              No
# 1          No             Yes
# 2          No              No
# ...

# %%
datos_account = pd.json_normalize(df['account'])
datos_account
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# ...

# %%
df.drop(['customer','phone','internet','account'], axis=1, inplace=True)

# %%
df
# Out:
#       customerID Churn
# 0     0002-ORFBO    No
# 1     0003-MKNFE    No
# 2     0004-TLHLJ   Yes
# 3     0011-IGKFF   Yes
# 4     0013-EXCHZ   Yes
# ...          ...   ...
# 7262  9987-LUTYD    No
# 7263  9992-RRAMN   Yes
# 7264  9992-UJOEL    No
# 7265  9993-LHIEB    No
# 7266  9995-HOTOH    No
#
# [7267 rows x 2 columns]

# %%
datos = df.join([datos_customer,datos_phone,datos_internet,datos_account])

# %%
datos.head(10)
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
# 5  0013-MHZWF    No  Female              0      No        Yes       9
# 6  0013-SMEOE    No  Female              1     Yes         No      71
# 7  0014-BMAQU    No    Male              0     Yes         No      63
# 8  0015-UOCOJ    No  Female              1      No         No       7
# 9  0016-QLJIS    No  Female              0     Yes        Yes      65
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# ...

# %%
datos.columns
# Out:
# Index(['customerID', 'Churn', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
datos['Charges.Total'].sample(10)
# Out:
# 5873     2341.5
# 6194    2820.65
# 3493    2043.45
# 515      6287.3
# 4801       20.4
# 4220     5232.9
# 9        5957.9
# 2942    2042.05
# 2485     676.15
# 3591       3410
# Name: Charges.Total, dtype: object

# %%
datos['Charges.Total'] = datos['Charges.Total'].str.replace(' ', '0').replace(',','.')

# %%
datos['Charges.Total'] = datos['Charges.Total'].astype(float)

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
datos.columns
# Out:
# Index(['customerID', 'Churn', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %%
datos.columns = ['ID_cliente', 'Churn', 'Genero', 'Tercera_edad', 'Partner',
'Dependientes', 'Antiguedad', 'Servicio_telefonico', 'Lineas_multiples',
'Servicio_de_internet', 'Seguridad_en_linea', 'Copia_de_seguridad_en_linea', 'Proteccion_del_dispositivo',
'Soporte_tecnico', 'Transmision_de_TV', 'Transmision_de_peliculas', 'Contrato',
'Facturacion_electronica', 'Metodo_de_pago', 'Cargos_mensuales',
'Cargos_totales']

# %%
datos.head(10)
# Out:
#    ID_cliente Churn  Genero  Tercera_edad Partner Dependientes  Antiguedad  \
# 0  0002-ORFBO    No  Female             0     Yes          Yes           9
# 1  0003-MKNFE    No    Male             0      No           No           9
# 2  0004-TLHLJ   Yes    Male             0      No           No           4
# 3  0011-IGKFF   Yes    Male             1     Yes           No          13
# 4  0013-EXCHZ   Yes  Female             1     Yes           No           3
# 5  0013-MHZWF    No  Female             0      No          Yes           9
# 6  0013-SMEOE    No  Female             1     Yes           No          71
# 7  0014-BMAQU    No    Male             0     Yes           No          63
# 8  0015-UOCOJ    No  Female             1      No           No           7
# 9  0016-QLJIS    No  Female             0     Yes          Yes          65
#
#   Servicio_telefonico Lineas_multiples Servicio_de_internet  ...  \
# 0                 Yes               No                  DSL  ...
# ...

# %%
datos['Churn'].unique()
# Out:
# array(['No', 'Yes', ''], dtype=object)

# %%
datos.query('Churn == ""')
# Out:
#       ID_cliente Churn  Genero  Tercera_edad Partner Dependientes  Antiguedad  \
# 30    0047-ZHDTW        Female             0      No           No          11
# 75    0120-YZLQA          Male             0      No           No          71
# 96    0154-QYHJU          Male             0      No           No          29
# 98    0162-RZGMZ        Female             1      No           No           5
# 175   0274-VVQOQ          Male             1     Yes           No          65
# ...          ...   ...     ...           ...     ...          ...         ...
# 7158  9840-GSRFX        Female             0      No           No          14
# 7180  9872-RZQQB        Female             0     Yes           No          49
# 7211  9920-GNDMB          Male             0      No           No           9
# 7239  9955-RVWSC        Female             0     Yes          Yes          67
# 7247  9966-VYRTZ        Female             0     Yes          Yes          31
#
# ...

# %%
churn_vacios = datos[datos['Churn'] == ''].index
datos = datos.drop(churn_vacios)

# %%
datos.query('Churn == ""')
# Out:
# Empty DataFrame
# Columns: [ID_cliente, Churn, Genero, Tercera_edad, Partner, Dependientes, Antiguedad, Servicio_telefonico, Lineas_multiples, Servicio_de_internet, Seguridad_en_linea, Copia_de_seguridad_en_linea, Proteccion_del_dispositivo, Soporte_tecnico, Transmision_de_TV, Transmision_de_peliculas, Contrato, Facturacion_electronica, Metodo_de_pago, Cargos_mensuales, Cargos_totales]
# Index: []
#
# [0 rows x 21 columns]

# %%
datos['Cuentas_Diarias'] = datos['Cargos_mensuales'] / 30

# %%
datos['Cuentas_Diarias'] = datos['Cuentas_Diarias'].round(2)

# %%
datos.head(10)
# Out:
#    ID_cliente Churn  Genero  Tercera_edad Partner Dependientes  Antiguedad  \
# 0  0002-ORFBO    No  Female             0     Yes          Yes           9
# 1  0003-MKNFE    No    Male             0      No           No           9
# 2  0004-TLHLJ   Yes    Male             0      No           No           4
# 3  0011-IGKFF   Yes    Male             1     Yes           No          13
# 4  0013-EXCHZ   Yes  Female             1     Yes           No           3
# 5  0013-MHZWF    No  Female             0      No          Yes           9
# 6  0013-SMEOE    No  Female             1     Yes           No          71
# 7  0014-BMAQU    No    Male             0     Yes           No          63
# 8  0015-UOCOJ    No  Female             1      No           No           7
# 9  0016-QLJIS    No  Female             0     Yes          Yes          65
#
#   Servicio_telefonico Lineas_multiples Servicio_de_internet  ...  \
# 0                 Yes               No                  DSL  ...
# ...

# %%
datos
# Out:
#       ID_cliente Churn  Genero  Tercera_edad Partner Dependientes  Antiguedad  \
# 0     0002-ORFBO    No  Female             0     Yes          Yes           9
# 1     0003-MKNFE    No    Male             0      No           No           9
# 2     0004-TLHLJ   Yes    Male             0      No           No           4
# 3     0011-IGKFF   Yes    Male             1     Yes           No          13
# 4     0013-EXCHZ   Yes  Female             1     Yes           No           3
# ...          ...   ...     ...           ...     ...          ...         ...
# 7262  9987-LUTYD    No  Female             0      No           No          13
# 7263  9992-RRAMN   Yes    Male             0     Yes           No          22
# 7264  9992-UJOEL    No    Male             0      No           No           2
# 7265  9993-LHIEB    No    Male             0     Yes          Yes          67
# 7266  9995-HOTOH    No    Male             0     Yes          Yes          63
#
# ...

# %%
datos['ID_cliente'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #📊 Carga y análisis

# %%
#Grafico de comparacion de los clientes que abandonaron el servicio y los que no

colores = ['deepskyblue', 'lightcoral','springgreen','darkviolet']
fig, axs = plt.subplots(1, 1, figsize=(8, 5))
plt.subplots_adjust(wspace=0.2, hspace=0.4)
datos['Churn'].value_counts().plot(ax=axs, kind='bar', color=colores)
axs.set_title('Comparación de evasión de clientes (Churn)')
axs.set_xlabel('')
axs.set_ylabel('Cantidad')
axs.set(xticklabels=['Clientes Activos', 'Clientes Retirados'])
axs.set_ylim(0,6000)
axs.spines['top'].set_visible(False)
axs.spines['right'].set_visible(False)
axs.set_xticklabels(axs.get_xticklabels(), rotation=360, ha='center')
porcentaje_churn = (datos['Churn'].value_counts()/datos['Churn'].value_counts().sum()) * 100
churn_p = {'Pno':round(porcentaje_churn.iloc[0],1),'Pyes':round(porcentaje_churn.iloc[1],1)}
churn_p = pd.Series(churn_p)
for i, count in enumerate(datos['Churn'].value_counts()):
    axs.text(i, count+100, str(f'{count} ({churn_p.iloc[i]}%)'), ha='center', fontsize=12)

plt.show()

# %%
datos_churns_genero = datos.groupby(['Genero','Churn']).size().unstack(fill_value=0)

fig, axs = plt.subplots(1, 2, figsize=(15, 5))
plt.subplots_adjust(wspace=0.3, hspace=0.4)
fig.suptitle('Evasión de clientes por Género', fontsize=12)
datos_churns_genero.T['Female'].plot(kind='bar', ax=axs[0], color=colores)
porcentaje_churn_generof = (datos_churns_genero.T['Female']/datos_churns_genero.T['Female'].sum()) * 100
axs[0].set_title('Evasión de clientes Femeninos')
axs[0].set_xlabel('Churn')
axs[0].set_ylabel('Numero de clientes')
axs[0].set(xticklabels=['Clientes Activos', 'Clientes Retirados'])
axs[0].set_ylim(0,3000)
axs[0].spines['top'].set_visible(False)
axs[0].spines['right'].set_visible(False)
#axs[0].grid()
axs[0].set_xticklabels(axs[0].get_xticklabels(), rotation=360, ha='center')
i=0
for p in axs[0].patches:

    axs[0].annotate(f"{int(p.get_height())} {round(porcentaje_churn_generof.iloc[i]),1}%",
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 5),
                textcoords='offset points')
    i +=1

datos_churns_genero.T['Male'].plot(kind='bar', ax=axs[1], color=colores)
porcentaje_churn_generom = (datos_churns_genero.T['Male']/datos_churns_genero.T['Male'].sum()) * 100
#axs[0].plot(datos_churns_genero.T['Female'])
axs[1].set_title('Evasión de clientes Masculinos')
axs[1].set_xlabel('Churn')
axs[1].set_ylabel('Numero de clientes')
axs[1].set(xticklabels=['Clientes Activos', 'Clientes Retirados'])
axs[1].set_ylim(0,3000)
axs[1].spines['top'].set_visible(False)
axs[1].spines['right'].set_visible(False)
i=0
for p in axs[1].patches:
    axs[1].annotate(f"{int(p.get_height())} {round(porcentaje_churn_generom.iloc[i]),1}%",
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 5),
                textcoords='offset points')
    i +=1


axs[1].set_xticklabels(axs[1].get_xticklabels(), rotation=360, ha='center')
plt.show()

# %%
datos_churns_tercera_edad = datos.groupby(['Tercera_edad','Churn']).size().unstack(fill_value=0)

datos_churns_tercera_edad.T
# Out:
# Tercera_edad     0    1
# Churn
# No            4508  666
# Yes           1393  476

# %%
datos_churns_tercera_edad = datos.groupby(['Tercera_edad','Churn']).size().unstack(fill_value=0)

fig, axs = plt.subplots(1, 2, figsize=(15, 5))
plt.subplots_adjust(wspace=0.3, hspace=0.4)
fig.suptitle('Evasión de clientes por Edad', fontsize=12)
datos_churns_tercera_edad.T[1].plot(kind='bar', ax=axs[0], color=colores)
porcentaje_churn_terceray = (datos_churns_tercera_edad.T[1]/datos_churns_tercera_edad.T[1].sum()) * 100
axs[0].set_title('Clientes que son de tercera edad')
axs[0].set_xlabel('Churn')
axs[0].set_ylabel('Numero de clientes')
axs[0].set(xticklabels=['Clientes Activos', 'Clientes Retirados'])
axs[0].set_ylim(0,800)
axs[0].spines['top'].set_visible(False)
axs[0].spines['right'].set_visible(False)
#axs[0].grid()
axs[0].set_xticklabels(axs[0].get_xticklabels(), rotation=360, ha='center')
i = 0
for p in axs[0].patches:
    axs[0].annotate(f"{int(p.get_height())} {round(porcentaje_churn_terceray.iloc[i]),1}%",
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 5),
                textcoords='offset points')
    i+=1
plt.xticks(rotation=360, ha='center')

datos_churns_tercera_edad.T[0].plot(kind='bar', ax=axs[1], color=colores)
porcentaje_churn_terceran = (datos_churns_tercera_edad.T[0]/datos_churns_tercera_edad.T[0].sum()) * 100
#axs[0].plot(datos_churns_genero.T['Female'])
axs[1].set_title('Clientes que no son de tercera edad')
axs[1].set_xlabel('Churn')
axs[1].set_ylabel('Numero de clientes')
axs[1].set_ylim(0,5000)
axs[1].spines['top'].set_visible(False)
axs[1].spines['right'].set_visible(False)
i = 0
for p in axs[1].patches:
    axs[1].annotate(f"{int(p.get_height())} {round(porcentaje_churn_terceran.iloc[i]),1}%",
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 5),
                textcoords='offset points')
    i+=1
axs[1].set_xticklabels(axs[0].get_xticklabels(), rotation=360, ha='center')
plt.show()

# %%
lista_servicios = [('Servicio_telefonico', 'Lineas_multiples'), ('Seguridad_en_linea', 'Copia_de_seguridad_en_linea'), ('Proteccion_del_dispositivo',
'Soporte_tecnico'), ('Transmision_de_TV', 'Transmision_de_peliculas')]

x = 0
for servicios in lista_servicios:
  i = 0
  fig, axs = plt.subplots(1, 2, figsize=(15, 5))
  plt.subplots_adjust(wspace=0.4, hspace=0.4)
  if x < 1:
    fig.suptitle('Evasión de clientes por Servicio', fontsize=12)
  datos_churns_servicios = datos.groupby([*servicios[0:1],'Churn']).size().unstack(fill_value=0)
  datos_churns_servicios.T['Yes'].plot(kind='bar', ax=axs[i], color=colores)
  porcentaje_datos_churns_servicios = (datos_churns_servicios.T['Yes']/datos_churns_servicios.T['Yes'].sum()) * 100
  titulo0 = str(*servicios[0:1]).replace('_', ' ')
  axs[i].set_title(f'Clientes de {titulo0}')
  axs[i].set_xlabel('Churn')
  axs[i].set_ylabel('Numero de clientes')
  axs[i].set(xticklabels=['Clientes Activos', 'Clientes Retirados'])
  #axs[i].set_ylim(0,800)
  axs[i].spines['top'].set_visible(False)
  axs[i].spines['right'].set_visible(False)
  #axs[i].grid()
  axs[i].set_xticklabels(axs[i].get_xticklabels(), rotation=360, ha='center')
  x = 0
  for p in axs[i].patches:
      axs[i].annotate(f"{int(p.get_height())} {round(porcentaje_datos_churns_servicios.iloc[x]),1}%",
                  (p.get_x() + p.get_width() / 2., p.get_height()),
                  ha='center', va='center',
                  xytext=(0, 5),
                  textcoords='offset points')
      x += 1
  plt.xticks(rotation=360, ha='center')
  i = 1
  datos_churns_servicios = datos.groupby([*servicios[1:2],'Churn']).size().unstack(fill_value=0)
  datos_churns_servicios.T['Yes'].plot(kind='bar', ax=axs[i], color=colores)
  porcentaje_datos_churns_servicios = (datos_churns_servicios.T['Yes']/datos_churns_servicios.T['Yes'].sum()) * 100
  titulo1 = str(*servicios[1:2]).replace('_', ' ')
  #titulo.replace('[^a-zA-Z]', ' ', regex=True)
  axs[i].set_title(f'Clientes de {titulo1}')
  axs[i].set_xlabel('Churn')
  axs[i].set_ylabel('Numero de clientes')
  axs[i].set(xticklabels=['Clientes Activos', 'Clientes Retirados'])
  #axs[i].set_ylim(0,800)
  axs[i].spines['top'].set_visible(False)
  axs[i].spines['right'].set_visible(False)
  #axs[i].grid()
  axs[i].set_xticklabels(axs[i].get_xticklabels(), rotation=360, ha='center')
  x = 0
  for p in axs[i].patches:
      axs[i].annotate(f"{int(p.get_height())} {round(porcentaje_datos_churns_servicios.iloc[x]),1}%",
                  (p.get_x() + p.get_width() / 2., p.get_height()),
                  ha='center', va='center',
                  xytext=(0, 5),
                  textcoords='offset points')
      x += 1
  plt.xticks(rotation=360, ha='center')
  plt.show()
  i = 0
  x +=1

# %%
datos_churns_servicio_de_internet = datos.groupby(['Servicio_de_internet','Churn']).size().unstack(fill_value=0)

fig, axs = plt.subplots(figsize=(15, 5))
plt.subplots_adjust(wspace=0.3, hspace=0.4)
fig.suptitle('Evasión de clientes por servicio de internet', fontsize=12, y=1.08)
datos_churns_servicio_de_internet.plot(kind='bar', ax=axs, color=colores)
porcentaje_datos_churns_servicios_de_internet = (datos_churns_servicio_de_internet.T/datos_churns_servicio_de_internet.T.sum()) * 100
#axs.set_title('Clientes por Metodo de pago')
#axs.set_xlabel('Churn')
axs.set_ylabel('Numero de clientes')
#axs.set(xticklabels=['Clientes Activos', 'Clientes Retirados'])
axs.set_ylim(0,2000)
axs.spines['top'].set_visible(False)
axs.spines['right'].set_visible(False)
#axs.grid()
axs.legend(labels=['Clientes Activos', 'Clientes Retirados'],loc='upper right',bbox_to_anchor=(0.56, 1.19))
axs.set_xticklabels(axs.get_xticklabels(), rotation=360, ha='center')
internet = ['No','Yes']
cantidades = []
for pi in internet:
    for psi in porcentaje_datos_churns_servicios_de_internet.T[pi]:
      cantidades.append(psi)
i = 0
for p in axs.patches:
  axs.annotate(f"{int(p.get_height())} {round(cantidades[i]),1}%",
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 5),
                textcoords='offset points')
  i +=1
plt.xticks(rotation=360, ha='center')
plt.show()

#porcentaje_datos_churns_servicios_de_internet[internet[0]]

# %%
datos_churns_metodo_pago = datos.groupby(['Metodo_de_pago','Churn']).size().unstack(fill_value=0)

fig, axs = plt.subplots(figsize=(20, 5))
plt.subplots_adjust(wspace=0.3, hspace=0.4)
fig.suptitle('Evasión de clientes por Metodo de pago', fontsize=12, y=1.05)
datos_churns_metodo_pago.plot(kind='bar', ax=axs, color=colores)
porcentaje_datos_churns_metodo_pago = (datos_churns_metodo_pago.T/datos_churns_metodo_pago.T.sum()) * 100
#axs.set_title('Clientes por Metodo de pago')
#axs.set_xlabel('Churn')
axs.set_ylabel('Numero de clientes')
#axs.set(xticklabels=['Clientes Activos', 'Clientes Retirados'])
axs.set_ylim(0,1400)
axs.spines['top'].set_visible(False)
axs.spines['right'].set_visible(False)
#axs.grid()
axs.legend(labels=['Clientes Activos', 'Clientes Retirados'],loc='upper right',bbox_to_anchor=(0.54, 1.15))
axs.set_xticklabels(axs.get_xticklabels(), rotation=360, ha='center')
metodo_pago = ['No','Yes']
cantidades = []
for mp in metodo_pago:
    for mpu in porcentaje_datos_churns_metodo_pago.T[mp]:
      cantidades.append(mpu)
i = 0
for p in axs.patches:
  axs.annotate(f"{int(p.get_height())} {round(cantidades[i]),1}%",
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 5),
                textcoords='offset points')
  i +=1
plt.xticks(rotation=360, ha='center')
plt.show()

# %%
datos_churns_por_contrato = datos.groupby(['Contrato','Churn']).size().unstack(fill_value=0)

fig, axs = plt.subplots(figsize=(17, 5))
plt.subplots_adjust(wspace=0.3, hspace=0.4)
fig.suptitle('Evasión de clientes por tipo de contrato', fontsize=12, y=1.05)
datos_churns_por_contrato.plot(kind='bar', ax=axs, color=colores)
porcentaje_datos_churns_por_contrato = (datos_churns_por_contrato.T/datos_churns_por_contrato.T.sum()) * 100
#axs.set_title('Clientes por tipo de contrato')
#axs.set_xlabel('Churn (Clientes)')
axs.set_ylabel('Numero de clientes')
#axs.set(xticklabels=['Clientes Activos', 'Clientes Retirados'])
axs.set_ylim(0,2400)
axs.spines['top'].set_visible(False)
axs.spines['right'].set_visible(False)
#axs.grid()
axs.legend(labels=['Clientes Activos', 'Clientes Retirados'],loc='upper right',bbox_to_anchor=(0.55, 1.15))
axs.set_xticklabels(axs.get_xticklabels(), rotation=360, ha='center')
contrato = ['No','Yes']
cantidades = []
for co in contrato:
    for cou in porcentaje_datos_churns_por_contrato.T[co]:
      cantidades.append(cou)
i = 0
for p in axs.patches:
    axs.annotate(f"{int(p.get_height())} {round(cantidades[i]),1}%",
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 5),
                textcoords='offset points')
    i+=1
plt.xticks(rotation=360, ha='center')
plt.show()

# %% [markdown]
# #📄Informe final

# %% [markdown]
# Luego de realizar la extracción de la información, importando los datos a un DataFrame, explayando los datos de cada columna, convirtiendo los datos para mejor legibilidad y transformando dichos datos para realizar la correcta comparación y un análisis que pueda generar más claridad para entender el porqué los clientes se están retirando del servicio de Telecom X.
#
# ## 🔹 **Comparación de evasión de clientes**
#
# Podemos observar el primer grafico que contiene la comparación de los clientes que están activos y los clientes que se han retirado del servicio:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Entendemos que se han retirado más del 25% de los clientes, con esto procedemos a realizar un análisis de los ordenados por género femenino y masculino:
#
#
# ## 🔹 **Comparación de evasión de clientes por género**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Mostrando así que casi la misma cantidad de clientes de ambos sexos se mantienen utilizando el servicio e igualmente la cantidad muy cercana de clientes que se han retirado del servicio.
#
# **Conclusión:** Esto da a entender que el género de los clientes no está influyendo en un razón para que los clientes se retiren, siendo asi que algo los esta afectando por igual sin importar el genero para que se retiren.

# %% [markdown]
# ## 🔹 **Comparación de evasión de clientes por edad**
#
# Ahora analizamos los clientes que pertenecen a la tercera edad y los que no:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# En esta comparación se puede observar una gran cantidad de evasión de clientes por parte de los que pertenecen a la tercera edad, tal vez no representen grandes números pero tomando en cuenta el total de clientes se observa que más de la mitad se ha retirado del servicio, y los clientes que no son de tercera edad son mas pero también está teniendo una gran cantidad de clientes que se están retirando, mas de mil clientes puede representar una pérdida muy considerable.
#
# **Conclusión:** En ambos casos se está teniendo grandes pérdidas, por lo que es un factor determinante de evasión de clientes, es recomendable realizar un análisis sobre el servicio prestado a estos clientes de tercera edad, como pueden ser la calidad del servicio, como suelen atender las preguntas ayudas de soporte técnico solicitados por los clientes, así como realizar breves encuentras para escuchar la opinión de los clientes y así por intentar mejorar el servicio en las áreas requeridas.

# %% [markdown]
# ## 🔹 **Comparación de evasión de clientes por servicio**
#
# En el siguiente análisis de la comparación de clientes por el tipo de servicio de utilizan:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Los clientes del servicio  de internet y sercivio telefónico son lo que más se han retirado servicio seguidos de los clientes de múltiples líneas, transmisión de TV y los de películas, estas 5 áreas representan el mayor problema de pérdida de clientes que está sucediendo.
#
# Las demás áreas también poseen pérdida de clientes pero esta es mucho menor a comparación con las 5 principales por lo que son a las que más se les debe prestar atención para comenzar a mitigar primero.
#
# **Conclusión:** Este es un factor determinante el cual es motivo de evasión de clientes y es necesario verificar la calidad, el soporte, la resolución de problemas, el tiempo de respuesta a los clientes y si es posible realizar encuentras para escuchar opiniones sobre estos servicios.

# %% [markdown]
# ## 🔹 **Comparación de evasión de clientes por metodos de pago utilizado**
#
# Analizando los metodos de pago que se ofrecen:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# El que hace que mas clientes se retiren es Eletronic check o Cheque eletronico, tanto que puede ser identificado como un patron por el cual los clientes que tienden a retirarse del servicio.
#
#
# **Conclusión:** El método de pago Eletronic check o Cheque electrónico es considerado uno de los factores determinantes de este problema. Se recomienda comenzar a analizar las posibles causas por las que este provoca esa reacción en los clientes, como pueden ser validar el funcionamiento de los servicios de pago, los posibles problemas que puede causar a la hora de realizar el pago, realizar breves encuestas o solicitar sugerencias a los clientes para saber cuál es el punto más importante que se debe tratar en este servicio.

# %% [markdown]
# ## 🔹 **Comparación de evasión de clientes por tipo de contrato**

# %% [markdown]
# En el analisis de los tipos de contrato que utilizan los clientes el contrato mensual es el que tiene la mayor perdidad de clientes, dando a reconocer otro patron por el que se puede predecir que los clientes que lo utilicen son los mas propensos a retirarse del servicio.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Los clientes de contrato mensual son un gran factor en la evasión de los clientes puesto que representa un gran número clientes retirados del servicio a comparación con los otros contratos que si tienen una gran retención de clientes y muy pocos abandonos del servicio.
#
# **Conclusión:** Se recomienda investigar si ocurre algún descontento en los clientes que ocupan este contrato para intentar ayudarlos y corregir este problema, y tal vez ofrecer algún beneficio o mejora a los clientes que contraten el plan mensual, para lograr así una retención mayor de clientes e intentar que consideren optar por alguno de los otros dos contratos de uno o dos años, puede ser ofreciendo alguna oferta especial o descuento si ocupan alguno de los otros contratos.

# %% [markdown]
# ## 🔹 **Resumen de recomendaciones según los análisis**

# %% [markdown]
# Las posibles recomendaciones para comenzar el análisis de pérdida de clientes del servicio e intentar aumentar las retenciones de los clientes:

# %% [markdown]
# - Realizar un análisis sobre el servicio prestado a estos clientes de tercera edad, como pueden ser la calidad del servicio, como suelen atender las preguntas ayudas de soporte técnico solicitados por los clientes, así como realizar breves encuentras para escuchar la opinión de los clientes y así por intentar mejorar el servicio en las áreas requeridas.
#
# - Verificar la calidad, el soporte, la resolución de problemas, el tiempo de respuesta a los clientes y si es posible realizar encuentras para escuchar opiniones sobre estos servicios.
#
# -  Validar el funcionamiento de los servicios de pago, los posibles problemas que puede causar a la hora de realizar el pago, realizar breves encuestas o solicitar sugerencias a los clientes para saber cuál es el punto más importante que se debe tratar en este servicio.
#
# -  Investigar si ocurre algún descontento en los clientes que ocupan este contrato para intentar ayudarlos y corregir este problema, y tal vez ofrecer algún beneficio o mejora a los clientes que contraten el plan mensual, para lograr así una retención mayor de clientes e intentar que consideren optar por alguno de los otros dos contratos de uno o dos años, puede ser ofreciendo alguna oferta especial o descuento si ocupan alguno de los otros contratos.
